# %% [markdown]
# # Lab 1. PyTorch and ANNs - Arash Nourimand Submission
#
# By the end of this lab, you should be able to:
#
# 1. Be able to perform basic PyTorch tensor operations.
# 2. Be able to load data into PyTorch
# 3. Be able to configure an Artificial Neural Network (ANN) using PyTorch
# 4. Be able to train ANNs using PyTorch
# 5. Be able to evaluate different ANN configuations

# %% [markdown]
# ## Colab Link
#
# Submit make sure to include a link to your colab file here
#
# Colab Link: https://colab.research.google.com/drive/1F-6XKJ5KzBudIowR__gwP0j-BLDKi7QJ

# %% [markdown]
# ## Part 1. Python Basics [9 pt]
#
# The purpose of this section is to get you used to the
# basics of Python, including working with functions, numbers,
# lists, and strings.
#
# Note that we **will** be checking your code for clarity and efficiency.
#
# If you have trouble with this part of the assignment, please review http://cs231n.github.io/python-numpy-tutorial/

# %% [markdown]
# ### Part (a) -- 3pt
#
# Write a function `sum_of_cubes` that computes the sum of cubes up to `n`. If the input to `sum_of_cubes` invalid (e.g. negative or non-integer `n`), the function should print out `"Invalid input"` and return `-1`.

# %%
def sum_of_cubes(n):
    """Return the sum (1^3 + 2^3 + 3^3 + ... + n^3)
    
    Precondition: n > 0, type(n) == int
    
    >>> sum_of_cubes(3)
    36
    >>> sum_of_cubes(1)
    1
    """
 
    # Condition to see if an input is an integer or negative
    while type(n) is not int or n<0:
      print("Invalid input")
      return (-1)
   
    sum = 0
    for i in range(1,n+1):
      sum = sum + i**3
    return(sum)

# Input for Sum of Cubes 
n = 13 # define number for n
sum_of_cubes(n)
# Out:
# 8281

# %% [markdown]
# ### Part (b) -- 3pt
#
# Write a function `word_lengths` that takes a sentence (string), computes the length of each word in that sentence, and returns the length of each word in a list. You can
# assume that words are always separated by a space character `" "`.
#
# Hint: recall the `str.split` function in Python.
# If you arenot sure how this function works, try
# typing `help(str.split)` into a Python shell, or check out https://docs.python.org/3.6/library/stdtypes.html#str.split

# %%
def word_lengths(sentence):
    """Return a list containing the length of each word in
    sentence.
    
    >>> word_lengths("welcome to APS360!")
    [7, 2, 7]
    >>> word_lengths("machine learning is so cool")
    [7, 8, 2, 2, 4]
    """
    
    # Turn the sentence input into an array of words
    words = sentence.split(" ") 
    # ^ makes an array that splits up the words in the sentence by a space
    n = len(words)
    num_list = []
    for i in range (n):
      num_list.append(len(words[i]))
    return(num_list)

sentence = "Hello, this is a test to ensure that this sentence criteria is functional" # Define the sentence
word_lengths(sentence)
# Out:
# [6, 4, 2, 1, 4, 2, 6, 4, 4, 8, 8, 2, 10]

# %% [markdown]
# ### Part (c) -- 3pt
#
# Write a function `all_same_length` that takes a sentence (string),
# and checks whether every word in the string is the same length.
# You should call the function `word_lengths` in the body
# of this new function.

# %%
def all_same_length(sentence):
    """Return True if every word in sentence has the same
    length, and False otherwise.
    
    >>> all_same_length("all same length")
    False
    >>> word_lengths("hello world")
    True
    """

    input_list = word_lengths(sentence) # Generate list with output of the sentence
    n = len(input_list) # Find the number of elements in the list for the incoming for loop
    m = input_list[0] # The length of the first word in the sentence
    for i in range(1,n):
      if input_list[i]!=m:
        return("False")
    return("True")
    
# Input step
sentence = "I am hungry" # Define the sentence

# Call the function for the input
all_same_length(sentence)
# Out:
# 'False'

# %% [markdown]
# ## Part 2. NumPy Exercises [11 pt]
#
# In this part of the assignment, you'll be manipulating arrays
# usign NumPy. Normally, we use the shorter name `np` to represent
# the package `numpy`.

# %%
import numpy as np

# %% [markdown]
# ### Part (a) -- 2pt
#
# The below variables `matrix` and `vector` are numpy arrays. Explain what you think `<NumpyArray>.size` and `<NumpyArray>.shape` represent.
#
# ### Answer:
# The size attribute gives the number of elements within a variable, wheras the shape attribute gives the dimensions of the variable

# %%
matrix = np.array([[1, 2., 3., 0.5],
                   [4., 5., 0., 0.],
                   [-1., -2., 1., 1.]])
vector = np.array([2, 0, 1, -2])

# %%
matrix.size
# Out:
# 12

# %%
matrix.shape
# Out:
# (3, 4)

# %%
vector.size
# Out:
# 4

# %%
vector.shape
# Out:
# (4,)

# %%
## ADDING IN THIS CELL TO AID IN THE VERIFICATION OF PART C --> WAS NOT HERE ORIGINALLY
matrix = np.array([[1, 2., 3., 0.5],
                   [4., 5., 0., 0.],
                   [-1., -2., 1., 1.]])
vector = np.array([2, 0, 1, -2])

# %% [markdown]
# ### Part (c) -- 3pt
#
# Perform matrix multiplication `output = matrix x vector` by using
# for loops to iterate through the columns and rows.
# Do not use any builtin NumPy functions.
# Cast your output into a NumPy array, if it isn't one already.
#
# Hint: be mindful of the dimension of output

# %%
# For matrix multiplication in this case: the column values of each element of "vector", will be multiplied by each column value for each row of "matrix", outputting a new 3x1 vector
(m,n) = matrix.shape # m = number of rows, and n = number of columns of matrix/number of rows of vector
new_vector = [] #define a new matrix for the output

# for loop to perform matrix multiplication

for i in range (m): # this will define the operation for the row elements in vector, for each row element of matrix
  s = 0 # declare dummy variable to carry over the additions for the multiplication 
  for j in range (n):
    s = s + (vector[j,]*matrix[i,j]) # performs matrix multiplication of matrix column elements and s replaces it's previous value
  new_vector.append(s) # appends s to the corresponding spot in the new vector
output = new_vector

# %%
output
# Out:
# [4.0, 8.0, -3.0]

# %% [markdown]
# ### Part (d) -- 1pt
#
# Perform matrix multiplication `output2 = matrix x vector` by using
# the function `numpy.dot`.
#
# We will never actually write code as in
# part(c), not only because `numpy.dot` is more concise and easier to read/write, but also performance-wise `numpy.dot` is much faster (it is written in C and highly optimized).
# In general, we will avoid for loops in our code.

# %%
new_matrix2 = np.dot(matrix,vector)
output2 = new_matrix2

# %%
output2
# Out:
# array([ 4.,  8., -3.])

# %%
import time

#-----------------FOR LOOP---------------------------
# record the time before running code for the for-loop
start_time1 = time.time()

# place code to run here
(m,n) = matrix.shape # m = number of rows, and n = number of columns of matrix/number of rows of vector
new_vector = [] #define a new matrix for the output

# for loop to perform matrix multiplication

for i in range (m): # this will define the operation for the row elements in vector, for each row element of matrix
  s = 0 # declare dummy variable to carry over the additions for the multiplication 
  for j in range (n):
    s = s + (vector[j,]*matrix[i,j]) # performs matrix multiplication of matrix column elements and s replaces it's previous value
  new_vector.append(s) # appends s to the corresponding spot in the new vector
output = new_vector
    
# record the time after the code is run for the for loop
end_time1 = time.time()

# compute the difference of the for loop
diff1 = end_time1 - start_time1

#-----------------NUMPY---------------------------
# record the time before running code for the numpy
start_time2 = time.time()

# place code to run here
new_matrix2 = np.dot(matrix,vector)
output2 = new_matrix2
    
# record the time after the code is run for the numpy
end_time2 = time.time()

# compute the difference of the for loop
diff2 = end_time2 - start_time2

print("time of for loop is", diff1)
print("time of the numpy is", diff2)
print("ratio of the for loop and numpy time is", (diff1/diff2))
# Out:
# time of for loop is 0.0002560615539550781
# time of the numpy is 0.00010967254638671875
# ratio of the for loop and numpy time is 2.3347826086956522

# %% [markdown]
# ## Part 3. Images [7 pt]
#
# A picture or image can be represented as a NumPy array of “pixels”,
# with dimensions H × W × C, where H is the height of the image, W is the width of the image,
# and C is the number of colour channels. Typically we will use an image with channels that give the the Red, Green, and Blue “level” of each pixel, which is referred to with the short form RGB.
#
# You will write Python code to load an image, and perform several array manipulations to the image and visualize their effects.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Part (a) -- 1 pt
#
# This is a photograph of a dog whose name is Mochi.
#
# ![alt text](https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews)
#
# Load the image from its url (https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews) into the variable `img` using the `plt.imread` function.

# %%
img = plt.imread("https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews")

# %% [markdown]
# ### Part (b) -- 1pt
#
# Use the function `plt.imshow` to visualize `img`.
#
# This function will also show the coordinate system used to identify pixels.
# The origin is at the top left corner, and the first dimension indicates the Y (row) direction,
# and the second dimension indicates the X (column) dimension.

# %%
plt.imshow(img)

# %% [markdown]
# ### Part (c) -- 2pt
#
# Modify the image by adding a constant value of 0.25 to each pixel in the `img` and
# store the result in the variable `img_add`. Display the image using `plt.imshow`.

# %%
# First: clip image values to nearest endpoint
img2 = np.clip(img,0,1)
img_add = 0.25+img2
plt.imshow(img_add)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# ----- NOT PART OF THE LAB RESPONSE ------------------------
# it appears multiplying the image by a scalar value changes the image saturation
plt.imshow(img2) # want to see the clipped and non-scalar modified version of the image looks like

# %% [markdown]
# ### Part (d) -- 3pt
#
# Crop the **original** image (`img` variable) to a 130 x 150 image including Mochi's face. Discard the alpha colour channel (i.e. resulting `img_cropped` should **only have RGB channels**)
#
# Display the image.

# %%
ims = img.shape #gives the dimensions of the image (350px high, 210px wide and 4 color channels - RGBA)
img_vec = [130,150] #define a vector of the cropped image size dimensions

# Mochi's face seems to be bounded by [20,110],[40,130] in x,y, respectively
img_bound_low = [20,40]
img_cropped = img[20:150, 40:190,0:3] # Defines the appropriate x/y dimensions and also 3 colors (i.e. eliminate the A color)
plt.imshow(img_cropped)

# %% [markdown]
# ## Part 4. Basics of PyTorch [12 pt]
#
# PyTorch is a Python-based neural networks package. Along with tensorflow, PyTorch is currently one of the most popular machine learning libraries.
#
# PyTorch, at its core, is similar to Numpy in a sense that they both
# try to make it easier to write codes for scientific computing
# achieve improved performance over vanilla Python by leveraging highly optimized C back-end.
# However, compare to Numpy, PyTorch offers much better GPU support and provides many high-level features for machine learning. Technically, Numpy can be used to perform almost every thing PyTorch does. However, Numpy would be a lot slower than PyTorch, especially with CUDA GPU, and it would take more effort to write machine learning related code compared to using PyTorch.

# %%
import torch

# %% [markdown]
# ### Part (a) -- 1 pt
#
# Use the function `torch.from_numpy` to convert the numpy array `img_cropped` into
# a PyTorch tensor. Save the result in a variable called `img_torch`.

# %%
img_torch = torch.from_numpy(img_cropped)
img_torch # generated output is a tensor
# Out:
# tensor([[[0.4157, 0.1725, 0.1216],
#          [0.4118, 0.1725, 0.0510],
#          [0.4745, 0.2392, 0.0275],
#          ...,
#          [0.4902, 0.2392, 0.0902],
#          [0.5020, 0.2510, 0.1020],
#          [0.5020, 0.2549, 0.0941]],
#
#         [[0.4275, 0.1843, 0.1333],
#          [0.4235, 0.1843, 0.0627],
#          [0.4863, 0.2510, 0.0392],
#          ...,
#          [0.4941, 0.2431, 0.0941],
#          [0.5059, 0.2549, 0.1059],
#          [0.5098, 0.2627, 0.1020]],
#
#         [[0.4314, 0.1882, 0.1373],
#          [0.4353, 0.1961, 0.0745],
#          [0.4980, 0.2627, 0.0510],
#          ...,
#          [0.4902, 0.2392, 0.0902],
#          [0.4980, 0.2471, 0.0980],
#          [0.5059, 0.2588, 0.0980]],
#
#         ...,
#
#         [[0.4431, 0.2235, 0.1176],
#          [0.4196, 0.1961, 0.0784],
#          [0.4510, 0.2235, 0.0784],
#          ...,
#          [0.5961, 0.4078, 0.2667],
#          [0.5882, 0.4000, 0.2588],
#          [0.5961, 0.4078, 0.2667]],
#
# ...

# %% [markdown]
# ### Part (b) -- 1pt
#
# Use the method `<Tensor>.shape` to find the shape (dimension and size) of `img_torch`.

# %%
img_torch.shape

print("the number of rows, columns and depth of the tensor are %d, %d and %d respectively" %(img_torch.shape[0],img_torch.shape[1], img_torch.shape[2])) # tensor of the size of the image; 130x150 px with 3 color definitions
# Out:
# the number of rows, columns and depth of the tensor are 130, 150 and 3 respectively

# %% [markdown]
# ### Part (c) -- 1pt
#
# How many floating-point numbers are stored in the tensor `img_torch`?

# %%
num_fp = img_torch.shape[0]*img_torch.shape[1]*img_torch.shape[2]
print("There are %d floating point elements" % num_fp)
# Out:
# There are 58500 floating point elements

# %% [markdown]
# ### Part (d) -- 3 pt
#
# What does the code `img_torch.transpose(0,2)` do? What does the expression return?
# Is the original variable `img_torch` updated? Explain.

# %%
# Testing the transpose
print(img_torch.transpose(0,2))

"The tensor is transposed, because the 0th and 2nd dimension of the tensor has changed, so the size of the tensor becomes 3x150x130."
"The original value of img_torch is not updated by the tranpose operation, unless the img_torch variable gets reassigned"
"to the transpose operation (i.e. img_torch = img_torch.transpose(x,y)"
# Out:
# 'The tensor is transposed, because the 0th and 2nd dimension of the tensor has changed, so the size of the tensor becomes 3x150x130. The original variable of img_torch would be updated'

# %% [markdown]
# ### Part (e) -- 3 pt
#
# What does the code `img_torch.unsqueeze(0)` do? What does the expression return?
# Is the original variable `img_torch` updated? Explain.

# %%
img_unsqueeze = img_torch.unsqueeze(0)
print(img_unsqueeze.size())
'The unsqueeze function adds another dimension to the tensor of size 1, appended at position 0. Essentially, what this does is generate a 4 dimensional tensor (i.e. the original 3D tensor abstracted to the new dimension of the unsqueezed tensor)'
'Like the transposition function, the value is not updated unless the value for img_torch is reassigned'
# Out:
# torch.Size([1, 130, 150, 3])
# 'The unsqueeze function adds another dimension to the tensor of size 1, appended at position 0. Essentially, what this does is generate a 4 dimensional tensor (i.e. the original 3D tensor abstracted to the new dimension of the unsqueezed tensor)'

# %% [markdown]
# ### Part (f) -- 3 pt
#
# Find the maximum value of `img_torch` along each colour channel? Your output should be a one-dimensional
# PyTorch tensor with exactly three values.

# %%
# Method: create an empty pytorch (1x3) tensor, and add each of the max RGB values to this tensor
# To do this, extract the R, G, B values respectively from the 3D tensor, and abstract it to a 2D 130x150 array. Then, the max value of that array will be the max R/G/B value
# R = 1st value, G = 2nd value, and B = 3rd value
rgb_tensor = torch.zeros(1,3) #Create empty tensor

for i in range(3): #for loop to extract the RGB 2D arrays to find the max value
  img_torch_array = img_torch[:, :, i] # generates a 2D tensor with only the 1st of the 3 values in each of the RGB vectors
  # print(img_torch_array.size()) # --> Checks that this gives a 130 x 150 matrix --> thus gives us each of the red values for each of the 19500 pixels]
  max_color_value = img_torch_array.max() #gives us the red tensor value
  rgb_tensor[:,i] = max_color_value

# Output of the RGB Tensor
rgb_tensor
# Out:
# tensor([[0.8941, 0.7882, 0.6745]])

# %% [markdown]
# ## Part 5. Training an ANN [11 pt]
#
# ### Part (a) -- 5 pt
# What is the best perforamce that you were able to obtain for identifying numbers greater or less than 3 and how did you obtain it? Please provide your code below.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt # for plotting
import torch.optim as optim

torch.manual_seed(1) # set the random seed

iterations = 20


# define a 2-layer artificial neural network
class Pigeon(nn.Module):
    def __init__(self):
        super(Pigeon, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 30)
        self.layer2 = nn.Linear(30, 1)
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = self.layer1(flattened)
        activation1 = F.relu(activation1) #preferred activation function, changing did not improve results
        activation2 = self.layer2(activation1)
        return activation2

pigeon = Pigeon()

# load the data
mnist_data = datasets.MNIST('data', train=True, download=True)
mnist_data = list(mnist_data)
mnist_train = mnist_data[:1000]
mnist_val   = mnist_data[1000:2000]
img_to_tensor = transforms.ToTensor()
      
    
# simplified training code to train `pigeon` on the "small digit recognition" task
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(pigeon.parameters(), lr=0.009, momentum=0.9)

# add a for loop to increase the number of iterations that the nn trains for (currently at 1)
for ii in range(iterations):
  for (image, label) in mnist_train:
      # actual ground truth: is the digit less than 3?
      actual = torch.tensor(label < 3).reshape([1,1]).type(torch.FloatTensor)
      # pigeon prediction
      out = pigeon(img_to_tensor(image)) # step 1-2
      # update the parameters based on the loss
      loss = criterion(out, actual)      # step 3
      loss.backward()                    # step 4 (compute the updates for each parameter)
      optimizer.step()                   # step 4 (make the updates for each parameter)
      optimizer.zero_grad()              # a clean up step for PyTorch

# computing the error and accuracy on the training set
error = 0
for (image, label) in mnist_train:
    prob = torch.sigmoid(pigeon(img_to_tensor(image)))
    if (prob < 0.5 and label < 3) or (prob >= 0.5 and label >= 3):
        error += 1
print("Training Error Rate:", error/len(mnist_train))
print("Training Accuracy:", 1 - error/len(mnist_train))


# computing the error and accuracy on a test set
error = 0
for (image, label) in mnist_val:
    prob = torch.sigmoid(pigeon(img_to_tensor(image)))
    if (prob < 0.5 and label < 3) or (prob >= 0.5 and label >= 3):
        error += 1
print("Test Error Rate:", error/len(mnist_val))
print("Test Accuracy:", 1 - error/len(mnist_val))
# Out:
# Training Error Rate: 0.0
# Training Accuracy: 1.0
# Test Error Rate: 0.053
# Test Accuracy: 0.947

# %% [markdown]
# ### Part (b) -- 3 pt
#
# Comment on which of the above changes resulted in the best accuracy on training data?

# %% [markdown]
# Changing the number of iterations to 20 allowed the nn to train 20x more than the initial condition and thus allowed a much higher accuracy due to optimizing the weightings of the layers to reduce errors (100%). Since model is at 100%, the model is overfit which means it might not perform as well under new datasets

# %% [markdown]
# ### Part (c) -- 3 pt
#
#
# Comment on which of the above changes resulted in the best accuracy on testing data?

# %% [markdown]
# For the testing set, it appears that changing the number of iterations helped as well. However, since there is a risk of overfitting if the NN gets trained too well on the training set, I also increased the learning rate to 0.009. Though this still yielded a 100% training accuracy, I achieved a maximum test accuracy of 94.7% in my experiments of modifying the parameters. I think the reason for this is because the learning rate allowed to find a consistent global minimum over the multiple iterations of training, which allowed for a high accuracy in the test stage.
